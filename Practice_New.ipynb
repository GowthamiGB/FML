# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv('drive/My Drive/FML/Data.csv')
dataset=data.copy()
dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
X=dataset.iloc[:,[0,1,2]].values
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, nan],
#        ['France', 35.0, 58000.0],
#        ['Spain', nan, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
Y=dataset.iloc[:,3].values
Y
# Out:
# array(['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
X=label.fit_transform(X[:,0])
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-448642c49d72> in <cell line: 3>()
#       1 from sklearn.preprocessing import LabelEncoder
#       2 label=LabelEncoder()
# ----> 3 X=label.fit_transform(X[:,0])
#       4 X
#
# NameError: name 'X' is not defined

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan, strategy='mean')
imputer=imputer.fit(X[:,[1,2]])
X[:,[1,2]]=imputer.transform(X[:,[1,2]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-b27c7cc41ae9> in <cell line: 3>()
#       1 from sklearn.impute import SimpleImputer
#       2 imputer=SimpleImputer(missing_values=np.nan, strategy='mean')
# ----> 3 imputer=imputer.fit(X[:,[1,2]])
#       4 X[:,[1,2]]=imputer.transform(X[:,[1,2]])
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
X
# Out:
# array([0, 2, 1, 2, 1, 0, 2, 0, 1, 0])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)
classifier.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
Y_pred=classifier.predict(X_test)
Y_pred
# Out:
# array(['Yes', 'Yes', 'No'], dtype=object)

# %%
Y_test
# Out:
# array(['No', 'No', 'Yes'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,Y_pred)
cm
# Out:
# array([[0, 2],
#        [1, 0]])

# %%
from sklearn import metrics
prediction=metrics.accuracy_score(Y_test,Y_pred)
print("accuracy:",prediction*100,'%')
# Out:
# accuracy: 0.0 %

# %%
from matplotlib.colors import ListedColormap
X_set,Y_set=X_train,Y_train
X1,X2=np.meshgrid(np.arange(start = X_set[:,0].min()-1, stop = X_set[:,0].max()+1 , step = 0.01),
np.arange(start = X_set[:,0].min()-1, stop = X_set[:,1].max()+1 , step = 0.01))
plt.contourf(X1,X2,classifier.predict(np.array([X1.ravel(),X2.ravel()]).T).reshape(X.shape), alpha=0.75,cmap=ListedColormap(("green","blue")))
for i,j in enumerate(np.unique(Y_set)):
  plt.scatter(X_set[Y_set==j,0],X_set[Y_set==j,1],c=ListedColormap(("green","blue"))(i),label=j)
  plt.title("Decision Tree Classifier(Training set)")
  plt.xlabel("Age")
  plt.ylabel("Salary")
  plt.legend()
  plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-deeca7dc758d> in <cell line: 5>()
#       3 X1,X2=np.meshgrid(np.arange(start = X_set[:,0].min()-1, stop = X_set[:,0].max()+1 , step = 0.01),
#       4 np.arange(start = X_set[:,0].min()-1, stop = X_set[:,1].max()+1 , step = 0.01))
# ----> 5 plt.contourf(X1,X2,classifier.predict(np.array([X1.ravel(),X2.ravel()]).T).reshape(X.shape), alpha=0.75,cmap=ListedColormap(("green","blue")))
#       6 for i,j in enumerate(np.unique(Y_set)):
#       7   plt.scatter(X_set[Y_set==j,0],X_set[Y_set==j,1],c=ListedColormap(("green","blue"))(i),label=j)
#
# ValueError: cannot reshape array of size 294300 into shape (10,2)
